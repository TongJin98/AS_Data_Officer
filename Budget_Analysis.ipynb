# %%
# Display plots directly in the notebook instead of in a new window
# %matplotlib inline

# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tabula

# %%
tabula.convert_into("Budget.pdf", "budget.csv", output_format="csv", pages='all')

# %%
df = pd.read_csv("budget.csv")
df = df[65:]
#df = df.dropna(subset=['Unnamed: 1'])
df
# Out:
#                          Pulse Referendum Carryforward  Unnamed: 1  \
# 65                             Office of the President         NaN
# 66                             Office of the President         NaN
# 67                                         Initiatives   $1,500.00
# 68                              Outreach and Marketing     $800.00
# 69                                              Travel   $5,000.00
# 70                                           Operating     $300.00
# 71                          Office of Student Advocacy         NaN
# 72                                     Operating Funds     $300.00
# 73                              Outreach and Marketing   $3,000.00
# 74                              Leadership Development   $1,300.00
# 75                    All Campus Commuter Board (ACCB)         NaN
# 76                             Social Power Hours (12)   $2,400.00
# 77                              Outreach and Promotion   $2,000.00
# 78                                           Workshops     $300.00
# 79                             Commuter Collaborations       $0.00
# 80                                    Dinner & A Movie       $0.00
# 81                           Breakfast at the Loop (6)     $900.00
# 82                                         Programming   $3,800.00
# 83                                           Marketing     $100.00
# 84                                     Townhall Events       $0.00
# 85                              Leadership Development     $300.00
# 86                                          Study Jams   $2,400.00
# 87                            Mentorship Pilot Program     $500.00
# 88                    fice of Enterprises and Services         NaN
# 89                                     A.S. Safe Rides  $36,000.00
# 90                             A.S. Safe Rides Reserve   $2,000.00
# 91                             Holiday Airport Shuttle   $9,000.00
# 92                                           Operating   $9,000.00
# 93                        Senior Memory Book Marketing     $750.00
# 94                                       Made to Order   $1,500.00
# 95                                           Marketing   $5,000.00
# 96                             Triton Television (TTV)         NaN
# 97                                       ACTA Stipends         NaN
# 98                       President (1 x $80/wk x 30wk)   $2,400.00
# 99                  Vice President (1 x $40/wk x 30wk)   $1,200.00
# 100                                      ACCB Stipends         NaN
# 101                          Chair (1 x $80/wk x 30wk)   $2,400.00
# 102                     Vice Chair (1 x $40/wk x 30wk)   $1,200.00
# 103                                     SOVAC Stipends         NaN
# 104             Executive Director (1 x $40/wk x 30wk)   $1,200.00
# 105                                     Other Stipends         NaN
# 106               Advocate General (1 x $15/wk x 30wk)     $450.00
# 107            Elections Director (1 x $40/wk x 20 wk)     $800.00
# 108                            Stipend Benefits (1.8%)         NaN
# 109  ALLOCATION OF EXPENDABLE FUNDS AFTER CAREER EM...         NaN
# 110  REMAINING FUNDS AFTER ALLOCATIONS (SURPLUS/DEF...         NaN
# 111                                                NaN         NaN
#
#      Unnamed: 2      $9,259.25
# 65          NaN     $84,850.00
# 66          NaN      $7,600.00
# 67          NaN            NaN
# 68          NaN            NaN
# 69          NaN            NaN
# 70          NaN            NaN
# 71          NaN      $4,600.00
# 72          NaN            NaN
# 73          NaN            NaN
# 74          NaN            NaN
# 75   $12,700.00            NaN
# 76          NaN            NaN
# 77          NaN            NaN
# 78          NaN            NaN
# 79          NaN            NaN
# 80          NaN            NaN
# 81          NaN            NaN
# 82          NaN            NaN
# 83          NaN            NaN
# 84          NaN            NaN
# 85          NaN            NaN
# 86          NaN            NaN
# 87          NaN            NaN
# 88          NaN            NaN
# 89          NaN            NaN
# 90          NaN            NaN
# 91          NaN            NaN
# 92          NaN            NaN
# 93          NaN            NaN
# 94          NaN            NaN
# 95          NaN            NaN
# 96   $33,689.00            NaN
# 97    $3,600.00            NaN
# 98          NaN            NaN
# 99          NaN            NaN
# 100   $3,600.00            NaN
# 101         NaN            NaN
# 102         NaN            NaN
# 103   $1,200.00            NaN
# 104         NaN            NaN
# 105         NaN      $1,250.00
# 106         NaN            NaN
# 107         NaN            NaN
# 108         NaN      $3,352.68
# 109         NaN  $2,987,039.85
# 110         NaN     $42,144.48
# 111         NaN          1.39%
