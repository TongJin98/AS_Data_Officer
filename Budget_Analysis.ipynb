# %%
# Display plots directly in the notebook instead of in a new window
# %matplotlib inline

# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tabula

# %%
df = pd.read_csv("budget.csv")

# %%
df = df[:338]

# %%
df.drop(df.columns[[0, 1]], axis = 1, inplace = True)

# %%
#take out the summary of each section
df = df[pd.notna(df['Unnamed: 6'])]

# %%
df.drop(df.columns[[0,3,5,6,7,8,9,10,11,12,13]], axis=1, inplace=True)
df
# Out:
#                                   Unnamed: 3  \
# 0                                Initiatives
# 1                     Outreach and Marketing
# 2                                     Travel
# 3                                  Operating
# 5                            Operating Funds
# 6                     Outreach and Marketing
# 7                     Leadership Development
# 9                                 Mixers (3)
# 10                    College Council Visits
# 11                      Council Peer Meetups
# 12                                 Operating
# 13                              Sun God Kits
# 14                                 Marketing
# 15                       All Council Retreat
# 16                               Programming
# 17                    Leadership Development
# 18                        Know Your Councils
# 19                              Muir Musical
# 21                               Programming
# 22                               A.S. Grants
# ...

# %%
#merge the first 2 columns
df_names = df['Unnamed: 3'].fillna(df['Unnamed: 4'])
df['Unnamed: 3'] = df_names
df.drop(df.columns[[1]], axis=1, inplace=True)

# %%
df = df.rename(columns={'Unnamed: 3': "category", 'Unnamed: 6': 'amount'})
df
# Out:
#                                               category      amount
# 0                                          Initiatives   $1,500.00
# 1                               Outreach and Marketing     $800.00
# 2                                               Travel   $5,000.00
# 3                                            Operating     $300.00
# 5                                      Operating Funds     $300.00
# 6                               Outreach and Marketing   $3,000.00
# 7                               Leadership Development   $1,300.00
# 9                                           Mixers (3)       $0.00
# 10                              College Council Visits     $200.00
# 11                                Council Peer Meetups     $550.00
# 12                                           Operating     $200.00
# 13                                        Sun God Kits     $600.00
# 14                                           Marketing     $200.00
# ...

# %%
df.to_excel(r'./cleaned_budget.xlsx')
